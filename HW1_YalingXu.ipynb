# %% [markdown]
# # HW1
# # Yaling Xu
#
# ## 1. Set your random seed to 1234

# %%
import random
random.seed(1234)

# %% [markdown]
# ## 2. Load the Fashion-MNIST dataset

# %%
from keras.datasets import mnist
from keras import models
from keras import layers
from keras import regularizers
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
random.seed(1234)
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
train_images = train_images.reshape((60000, 28 * 28)).astype('float32') / 255
test_images = test_images.reshape((10000, 28 * 28)).astype('float32') / 255
train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)
train_images, valid_images, train_labels, valid_labels = train_test_split(train_images, train_labels, test_size = 0.16666, random_state = 1234)

# %% [markdown]
# ## 3.Implement a series of neural network models
# ### (1) Initial Test

# %%
nw_org = models.Sequential()
nw_org.add(layers.Dense(512, activation='relu', input_shape= (28 * 28,)))
nw_org.add(layers.Dense(512, activation='relu'))
nw_org.add(layers.Dense(512, activation='relu'))
nw_org.add(layers.Dense(512, activation='relu'))
nw_org.add(layers.Dense(10, activation='softmax'))
nw_org.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])
result_org = nw_org.fit(train_images, train_labels,validation_data=(valid_images,valid_labels), epochs=200, batch_size=512)
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/200
# 50000/50000 [==============================] - 10s 209us/step - loss: 0.5061 - acc: 0.8393 - val_loss: 0.1718 - val_acc: 0.9482
# Epoch 2/200
# 50000/50000 [==============================] - 9s 188us/step - loss: 0.1567 - acc: 0.9528 - val_loss: 0.1435 - val_acc: 0.9548
# Epoch 3/200
# 50000/50000 [==============================] - 9s 185us/step - loss: 0.0927 - acc: 0.9715 - val_loss: 0.0990 - val_acc: 0.9709
# Epoch 4/200
# 50000/50000 [==============================] - 9s 190us/step - loss: 0.0649 - acc: 0.9801 - val_loss: 0.0885 - val_acc: 0.9733
# Epoch 5/200
# 50000/50000 [==============================] - 11s 221us/step - loss: 0.0457 - acc: 0.9863 - val_loss: 0.0719 - val_acc: 0.9777
# Epoch 6/200
# 50000/50000 [==============================] - 10s 199us/step - loss: 0.0371 - acc: 0.9893 - val_loss: 0.0781 - val_acc: 0.9780
# Epoch 7/200
# ...

# %%
val_acc = result_org.history['val_acc']
val_loss = result_org.history['val_loss']
plt.plot(val_acc)
plt.plot(val_loss)
plt.legend(['val_acc', 'val_loss'])
plt.title('Validation Accuracy & LossC in Initial Test')
plt.show()

# %% [markdown]
# In this model, the accuracy starts to keep unchanged after 10 epochs while the loss gets worse after about 10 epochs. It has the best perform on about 5 epochs.
#
# ### (2) Implement dropout

# %%
# Implement layer dropout after each layer from model 1 (except the last) and use a dropout rate of 0.5

# %%
nw_dropout = models.Sequential()
nw_dropout.add(layers.Dense(512, activation='relu', input_shape=(28 * 28,)))
nw_dropout.add(layers.Dropout(0.5))
nw_dropout.add(layers.Dense(512, activation='relu'))
nw_dropout.add(layers.Dropout(0.5))
nw_dropout.add(layers.Dense(512, activation='relu'))
nw_dropout.add(layers.Dropout(0.5))
nw_dropout.add(layers.Dense(512, activation='relu'))
nw_dropout.add(layers.Dropout(0.5))
nw_dropout.add(layers.Dense(10, activation='softmax'))
nw_dropout.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])
result_dropout = nw_dropout.fit(train_images, train_labels,validation_data=(valid_images,valid_labels), epochs=200, batch_size=512)
# Out:
# WARNING:tensorflow:From /Users/yalingxu/anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/200
# 50000/50000 [==============================] - 6s 128us/step - loss: 0.7193 - acc: 0.7612 - val_loss: 0.2216 - val_acc: 0.9346
# Epoch 2/200
# 50000/50000 [==============================] - 6s 114us/step - loss: 0.2667 - acc: 0.9225 - val_loss: 0.1548 - val_acc: 0.9530
# Epoch 3/200
# 50000/50000 [==============================] - 6s 121us/step - loss: 0.1987 - acc: 0.9431 - val_loss: 0.1286 - val_acc: 0.9636
# Epoch 4/200
# 50000/50000 [==============================] - 6s 127us/step - loss: 0.1644 - acc: 0.9538 - val_loss: 0.1106 - val_acc: 0.9680
# ...

# %%
val_acc = result_org.history['val_acc']
val_loss = result_org.history['val_loss']
val_acc_dropout = result_dropout.history['val_acc']
val_loss_dropout = result_dropout.history['val_loss']

# graphically compare the validation loss across epochs to the initial model
plt.plot(val_acc)
plt.plot(val_loss)
plt.plot(val_acc_dropout)
plt.plot(val_loss_dropout)
plt.legend(['val_acc', 'val_loss', 'val_acc_dropout', 'val_loss_dropout'])
plt.title('Validation Accuracy & Loss in Original Model and Dropout Model')
plt.show()

# %% [markdown]
# In terms of the validation set accuracy, original model and dropout model are nearly same. However, the dropout model shows slightly better than the original model in the validation set loss since it decrease the overfitting problem.
#
# ### (3) Weight regularization

# %% [markdown]
# **Reestimate the initial model with L1 weight regularization on each layer (except the final layer) with a 0.001 penalty for each weight coefficient.**

# %%
network_l1 = models.Sequential()
network_l1.add(layers.Dense(512, activation='relu', input_shape=(28 * 28,), kernel_regularizer=regularizers.l1(0.001)))
network_l1.add(layers.Dense(512, activation='relu', kernel_regularizer=regularizers.l1(0.001)))
network_l1.add(layers.Dense(512, activation='relu', kernel_regularizer=regularizers.l1(0.001)))
network_l1.add(layers.Dense(512, activation='relu', kernel_regularizer=regularizers.l1(0.001)))
network_l1.add(layers.Dense(10, activation='softmax'))
network_l1.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])
result_l1 = network_l1.fit(train_images, train_labels,validation_data=(valid_images,valid_labels), epochs=200, batch_size=512)
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/200
# 50000/50000 [==============================] - 6s 113us/step - loss: 13.5845 - acc: 0.6740 - val_loss: 3.8027 - val_acc: 0.8445
# Epoch 2/200
# 50000/50000 [==============================] - 6s 115us/step - loss: 2.9745 - acc: 0.7938 - val_loss: 2.5511 - val_acc: 0.7677
# Epoch 3/200
# 50000/50000 [==============================] - 6s 113us/step - loss: 2.1619 - acc: 0.8303 - val_loss: 1.9631 - val_acc: 0.8435
# Epoch 4/200
# 50000/50000 [==============================] - 6s 121us/step - loss: 1.8508 - acc: 0.8574 - val_loss: 1.7107 - val_acc: 0.8822
# Epoch 5/200
# 50000/50000 [==============================] - 6s 118us/step - loss: 1.6704 - acc: 0.8749 - val_loss: 1.5756 - val_acc: 0.8918
# Epoch 6/200
# 50000/50000 [==============================] - 6s 124us/step - loss: 1.5650 - acc: 0.8847 - val_loss: 1.5499 - val_acc: 0.8787
# Epoch 7/200
# ...

# %% [markdown]
# **Reestimate the initial model with L2 weight regularization on each layer (except the final layer) with a 0.001 penalty for each weight coefficient.**

# %%
network_l2 = models.Sequential()
network_l2.add(layers.Dense(512, activation='relu', input_shape=(28 * 28,), kernel_regularizer=regularizers.l2(0.001)))
network_l2.add(layers.Dense(512, activation='relu', kernel_regularizer=regularizers.l2(0.001)))
network_l2.add(layers.Dense(512, activation='relu', kernel_regularizer=regularizers.l2(0.001)))
network_l2.add(layers.Dense(512, activation='relu', kernel_regularizer=regularizers.l2(0.001)))
network_l2.add(layers.Dense(10, activation='softmax'))
network_l2.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])
result_l2 = network_l2.fit(train_images, train_labels,validation_data=(valid_images,valid_labels), epochs=200, batch_size=512)
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/200
# 50000/50000 [==============================] - 6s 130us/step - loss: 1.8274 - acc: 0.8242 - val_loss: 1.1414 - val_acc: 0.9082
# Epoch 2/200
# 50000/50000 [==============================] - 6s 114us/step - loss: 0.8558 - acc: 0.9351 - val_loss: 0.8691 - val_acc: 0.8843
# Epoch 3/200
# 50000/50000 [==============================] - 5s 102us/step - loss: 0.5507 - acc: 0.9505 - val_loss: 0.4307 - val_acc: 0.9644
# Epoch 4/200
# 50000/50000 [==============================] - 5s 99us/step - loss: 0.4139 - acc: 0.9573 - val_loss: 0.3595 - val_acc: 0.9659
# Epoch 5/200
# 50000/50000 [==============================] - 5s 101us/step - loss: 0.3319 - acc: 0.9650 - val_loss: 0.3027 - val_acc: 0.9669
# Epoch 6/200
# 50000/50000 [==============================] - 5s 97us/step - loss: 0.2892 - acc: 0.9681 - val_loss: 0.2642 - val_acc: 0.9712
# Epoch 7/200
# ...

# %% [markdown]
# **Plot the validation loss for the initial model vs. the dropout vs. the L1 regularized model vs. the L2 regularized model - which model appears to perform the best?**

# %%
val_loss_org = result_org.history['val_loss']
val_loss_dropout = result_dropout.history['val_loss']
val_loss_l1 = result_l1.history['val_loss']
val_loss_l2 = result_l2.history['val_loss']

plt.plot(val_loss_org)
plt.plot(val_loss_dropout)
plt.plot(val_loss_l1)
plt.plot(val_loss_l2)
plt.legend(['val_loss_org', 'val_loss_dropout', 'val_loss_l1', 'val_loss_l2'])
plt.title('Validation Accuracy & Loss in Original Model vs Dropout Model vs L1/L2 Weight Regularized Model')
plt.show()

# %% [markdown]
# The L1 regularized model performs worst. The dropout model has a constant good performance for all epochs while the L2 regularized model performs slightly better for large epoch number.

# %% [markdown]
# ### 4. Alternative models
#
# Apparently, most of models have best performance before 20 epochs from the analysis above. Thus I would only make 40 epochs in the following analysis in order to save resourse and avoid overfitting. Additionally, even though there may exist minimum loss and better performance, it is highly not likly to appear after 200 epochs.

# %%
#1 dropout model for four layers 
nw_drop_4layer = models.Sequential()
nw_drop_4layer.add(layers.Dense(512, activation='relu', input_shape=(28 * 28,)))
nw_drop_4layer.add(layers.Dropout(0.5))
nw_drop_4layer.add(layers.Dense(512, activation='relu'))
nw_drop_4layer.add(layers.Dropout(0.5))
nw_drop_4layer.add(layers.Dense(512, activation='relu'))
nw_drop_4layer.add(layers.Dropout(0.5))
nw_drop_4layer.add(layers.Dense(10, activation='softmax'))
nw_drop_4layer.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])

result_drop_4layer = nw_drop_4layer.fit(train_images, train_labels,validation_data=(valid_images,valid_labels), epochs=40, batch_size=512)
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/40
# 50000/50000 [==============================] - 6s 113us/step - loss: 0.5811 - acc: 0.8128 - val_loss: 0.2145 - val_acc: 0.9318
# Epoch 2/40
# 50000/50000 [==============================] - 5s 94us/step - loss: 0.2368 - acc: 0.9297 - val_loss: 0.1557 - val_acc: 0.9514
# Epoch 3/40
# 50000/50000 [==============================] - 5s 97us/step - loss: 0.1737 - acc: 0.9483 - val_loss: 0.1198 - val_acc: 0.9636
# Epoch 4/40
# 50000/50000 [==============================] - 5s 99us/step - loss: 0.1443 - acc: 0.9577 - val_loss: 0.1028 - val_acc: 0.9683
# Epoch 5/40
# 50000/50000 [==============================] - 5s 95us/step - loss: 0.1232 - acc: 0.9639 - val_loss: 0.0884 - val_acc: 0.9732
# Epoch 6/40
# 50000/50000 [==============================] - 5s 90us/step - loss: 0.1116 - acc: 0.9664 - val_loss: 0.1031 - val_acc: 0.9691
# Epoch 7/40
# ...

# %%
#2 dropout model for three layers 
nw_drop_3layer = models.Sequential()
nw_drop_3layer.add(layers.Dense(512, activation='relu', input_shape=(28 * 28,)))
nw_drop_3layer.add(layers.Dropout(0.5))
nw_drop_3layer.add(layers.Dense(512, activation='relu'))
nw_drop_3layer.add(layers.Dropout(0.5))
nw_drop_3layer.add(layers.Dense(10, activation='softmax'))
nw_drop_3layer.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])

result_drop_3layer = nw_drop_3layer.fit(train_images, train_labels,validation_data=(valid_images,valid_labels), epochs=40, batch_size=512)
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/40
# 50000/50000 [==============================] - 4s 80us/step - loss: 0.4969 - acc: 0.8446 - val_loss: 0.2194 - val_acc: 0.9347
# Epoch 2/40
# 50000/50000 [==============================] - 3s 58us/step - loss: 0.2124 - acc: 0.9361 - val_loss: 0.1367 - val_acc: 0.9566
# Epoch 3/40
# 50000/50000 [==============================] - 3s 61us/step - loss: 0.1568 - acc: 0.9528 - val_loss: 0.1158 - val_acc: 0.9636
# Epoch 4/40
# 50000/50000 [==============================] - 3s 61us/step - loss: 0.1268 - acc: 0.9616 - val_loss: 0.0963 - val_acc: 0.9706
# Epoch 5/40
# 50000/50000 [==============================] - 3s 66us/step - loss: 0.1083 - acc: 0.9670 - val_loss: 0.0815 - val_acc: 0.9738
# Epoch 6/40
# 50000/50000 [==============================] - 3s 63us/step - loss: 0.0969 - acc: 0.9700 - val_loss: 0.0834 - val_acc: 0.9746
# Epoch 7/40
# ...

# %%
#3 dropout model for six layers 
nw_drop_6layer = models.Sequential()
nw_drop_6layer.add(layers.Dense(512, activation='relu', input_shape=(28 * 28,)))
nw_drop_6layer.add(layers.Dropout(0.5))
nw_drop_6layer.add(layers.Dense(512, activation='relu'))
nw_drop_6layer.add(layers.Dropout(0.5))
nw_drop_6layer.add(layers.Dense(512, activation='relu'))
nw_drop_6layer.add(layers.Dropout(0.5))
nw_drop_6layer.add(layers.Dense(512, activation='relu'))
nw_drop_6layer.add(layers.Dropout(0.5))
nw_drop_6layer.add(layers.Dense(512, activation='relu'))
nw_drop_6layer.add(layers.Dropout(0.5))
nw_drop_6layer.add(layers.Dense(10, activation='softmax'))
nw_drop_6layer.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])

result_drop_6layer = nw_drop_6layer.fit(train_images, train_labels,validation_data=(valid_images,valid_labels), epochs=40, batch_size=512)
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/40
# 50000/50000 [==============================] - 5s 109us/step - loss: 0.5901 - acc: 0.8089 - val_loss: 0.1971 - val_acc: 0.9371
# Epoch 2/40
# 50000/50000 [==============================] - 4s 87us/step - loss: 0.2286 - acc: 0.9312 - val_loss: 0.1985 - val_acc: 0.9390
# Epoch 3/40
# 50000/50000 [==============================] - 4s 90us/step - loss: 0.1750 - acc: 0.9481 - val_loss: 0.1198 - val_acc: 0.9621
# Epoch 4/40
# 50000/50000 [==============================] - 4s 88us/step - loss: 0.1437 - acc: 0.9581 - val_loss: 0.1059 - val_acc: 0.9676
# Epoch 5/40
# 50000/50000 [==============================] - 4s 88us/step - loss: 0.1233 - acc: 0.9637 - val_loss: 0.0813 - val_acc: 0.9753
# Epoch 6/40
# 50000/50000 [==============================] - 4s 88us/step - loss: 0.1103 - acc: 0.9675 - val_loss: 0.0837 - val_acc: 0.9752
# Epoch 7/40
# ...

# %%
#4 dropout model for five layers and 0.3 dropout rate 
nw_drop_5layer_03r = models.Sequential()
nw_drop_5layer_03r.add(layers.Dense(512, activation='relu', input_shape=(28 * 28,)))
nw_drop_5layer_03r.add(layers.Dropout(0.3))
nw_drop_5layer_03r.add(layers.Dense(512, activation='relu'))
nw_drop_5layer_03r.add(layers.Dropout(0.3))
nw_drop_5layer_03r.add(layers.Dense(512, activation='relu'))
nw_drop_5layer_03r.add(layers.Dropout(0.3))
nw_drop_5layer_03r.add(layers.Dense(512, activation='relu'))
nw_drop_5layer_03r.add(layers.Dropout(0.3))
nw_drop_5layer_03r.add(layers.Dense(10, activation='softmax'))
nw_drop_5layer_03r.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])

result_drop_5layer_03r = nw_drop_5layer_03r.fit(train_images, train_labels,validation_data=(valid_images,valid_labels), epochs=40, batch_size=512)
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/40
# 50000/50000 [==============================] - 8s 164us/step - loss: 0.5679 - acc: 0.8164 - val_loss: 0.2083 - val_acc: 0.9367
# Epoch 2/40
# 50000/50000 [==============================] - 7s 140us/step - loss: 0.1952 - acc: 0.9423 - val_loss: 0.1267 - val_acc: 0.9618
# Epoch 3/40
# 50000/50000 [==============================] - 7s 137us/step - loss: 0.1374 - acc: 0.9604 - val_loss: 0.0958 - val_acc: 0.9703
# Epoch 4/40
# 50000/50000 [==============================] - 6s 125us/step - loss: 0.1070 - acc: 0.9677 - val_loss: 0.0861 - val_acc: 0.9740
# Epoch 5/40
# 50000/50000 [==============================] - 6s 122us/step - loss: 0.0871 - acc: 0.9748 - val_loss: 0.0939 - val_acc: 0.9717
# Epoch 6/40
# 50000/50000 [==============================] - 6s 120us/step - loss: 0.0744 - acc: 0.9782 - val_loss: 0.0762 - val_acc: 0.9781
# Epoch 7/40
# ...

# %%
#5 dropout model for five layers and 0.7 dropout rate 
nw_drop_5layer_07r = models.Sequential()
nw_drop_5layer_07r.add(layers.Dense(512, activation='relu', input_shape=(28 * 28,)))
nw_drop_5layer_07r.add(layers.Dropout(0.7))
nw_drop_5layer_07r.add(layers.Dense(512, activation='relu'))
nw_drop_5layer_07r.add(layers.Dropout(0.7))
nw_drop_5layer_07r.add(layers.Dense(512, activation='relu'))
nw_drop_5layer_07r.add(layers.Dropout(0.7))
nw_drop_5layer_07r.add(layers.Dense(512, activation='relu'))
nw_drop_5layer_07r.add(layers.Dropout(0.7))
nw_drop_5layer_07r.add(layers.Dense(10, activation='softmax'))
nw_drop_5layer_07r.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])

result_drop_5layer_07r = nw_drop_5layer_07r.fit(train_images, train_labels,validation_data=(valid_images,valid_labels), epochs=40, batch_size=512)
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/40
# 50000/50000 [==============================] - 8s 152us/step - loss: 1.5179 - acc: 0.4504 - val_loss: 0.5052 - val_acc: 0.8746
# Epoch 2/40
# 50000/50000 [==============================] - 6s 125us/step - loss: 0.5810 - acc: 0.8204 - val_loss: 0.2668 - val_acc: 0.9270
# Epoch 3/40
# 50000/50000 [==============================] - 6s 125us/step - loss: 0.4085 - acc: 0.8886 - val_loss: 0.2139 - val_acc: 0.9425
# Epoch 4/40
# 50000/50000 [==============================] - 6s 129us/step - loss: 0.3324 - acc: 0.9110 - val_loss: 0.1850 - val_acc: 0.9512
# Epoch 5/40
# 50000/50000 [==============================] - 6s 124us/step - loss: 0.3017 - acc: 0.9220 - val_loss: 0.1757 - val_acc: 0.9525
# Epoch 6/40
# 50000/50000 [==============================] - 6s 116us/step - loss: 0.2680 - acc: 0.9312 - val_loss: 0.1627 - val_acc: 0.9573
# Epoch 7/40
# ...

# %%
#6 Initial model for five layers and 300 batch size
nw_5layer_300bs = models.Sequential()
nw_5layer_300bs.add(layers.Dense(512, activation='relu', input_shape=(28 * 28,)))
nw_5layer_300bs.add(layers.Dense(512, activation='relu'))
nw_5layer_300bs.add(layers.Dense(512, activation='relu'))
nw_5layer_300bs.add(layers.Dense(512, activation='relu'))
nw_5layer_300bs.add(layers.Dense(10, activation='softmax'))
nw_5layer_300bs.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])

result_nw_5layer_300bs = nw_5layer_300bs.fit(train_images, train_labels,validation_data=(valid_images,valid_labels), epochs=40, batch_size=300)
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/40
# 50000/50000 [==============================] - 7s 147us/step - loss: 0.3832 - acc: 0.8789 - val_loss: 0.1929 - val_acc: 0.9391
# Epoch 2/40
# 50000/50000 [==============================] - 6s 130us/step - loss: 0.1219 - acc: 0.9633 - val_loss: 0.1034 - val_acc: 0.9684
# Epoch 3/40
# 50000/50000 [==============================] - 5s 110us/step - loss: 0.0797 - acc: 0.9762 - val_loss: 0.1076 - val_acc: 0.9652
# Epoch 4/40
# 50000/50000 [==============================] - 6s 114us/step - loss: 0.0559 - acc: 0.9835 - val_loss: 0.0951 - val_acc: 0.9718
# Epoch 5/40
# 50000/50000 [==============================] - 6s 116us/step - loss: 0.0419 - acc: 0.9876 - val_loss: 0.0859 - val_acc: 0.9773
# Epoch 6/40
# 50000/50000 [==============================] - 6s 118us/step - loss: 0.0330 - acc: 0.9903 - val_loss: 0.1248 - val_acc: 0.9679
# Epoch 7/40
# ...

# %%
#7 Initial model for five layers and 700 batch size
nw_5layer_700bs = models.Sequential()
nw_5layer_700bs.add(layers.Dense(512, activation='relu', input_shape=(28 * 28,)))
nw_5layer_700bs.add(layers.Dense(512, activation='relu'))
nw_5layer_700bs.add(layers.Dense(512, activation='relu'))
nw_5layer_700bs.add(layers.Dense(512, activation='relu'))
nw_5layer_700bs.add(layers.Dense(10, activation='softmax'))
nw_5layer_700bs.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])

result_nw_5layer_700bs = nw_5layer_700bs.fit(train_images, train_labels,validation_data=(valid_images,valid_labels), epochs=40, batch_size=700)
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/40
# 50000/50000 [==============================] - 7s 132us/step - loss: 0.5917 - acc: 0.8086 - val_loss: 0.2701 - val_acc: 0.9170
# Epoch 2/40
# 50000/50000 [==============================] - 5s 107us/step - loss: 0.1844 - acc: 0.9442 - val_loss: 0.1863 - val_acc: 0.9436
# Epoch 3/40
# 50000/50000 [==============================] - 6s 118us/step - loss: 0.1232 - acc: 0.9631 - val_loss: 0.1093 - val_acc: 0.9673
# Epoch 4/40
# 50000/50000 [==============================] - 6s 117us/step - loss: 0.0781 - acc: 0.9765 - val_loss: 0.1345 - val_acc: 0.9596
# Epoch 5/40
# 50000/50000 [==============================] - 5s 103us/step - loss: 0.0619 - acc: 0.9812 - val_loss: 0.1168 - val_acc: 0.9617
# Epoch 6/40
# 50000/50000 [==============================] - 5s 102us/step - loss: 0.0408 - acc: 0.9870 - val_loss: 0.2514 - val_acc: 0.9414
# Epoch 7/40
# ...

# %%
#8 L1 regularized model for three layers
nw_l1_3layer = models.Sequential()
nw_l1_3layer.add(layers.Dense(512, activation='relu', input_shape=(28 * 28,), kernel_regularizer=regularizers.l1(0.001)))
nw_l1_3layer.add(layers.Dense(512, activation='relu', kernel_regularizer=regularizers.l1(0.001)))
nw_l1_3layer.add(layers.Dense(10, activation='softmax'))
nw_l1_3layer.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])
result_l1_3layer = nw_l1_3layer.fit(train_images, train_labels,validation_data=(valid_images,valid_labels), epochs=40, batch_size=512)
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/40
# 50000/50000 [==============================] - 5s 90us/step - loss: 7.9140 - acc: 0.7938 - val_loss: 2.4403 - val_acc: 0.8680
# Epoch 2/40
# 50000/50000 [==============================] - 3s 57us/step - loss: 1.8455 - acc: 0.8588 - val_loss: 1.4515 - val_acc: 0.8807
# Epoch 3/40
# 50000/50000 [==============================] - 3s 58us/step - loss: 1.3234 - acc: 0.8826 - val_loss: 1.2035 - val_acc: 0.8885
# Epoch 4/40
# 50000/50000 [==============================] - 4s 73us/step - loss: 1.1242 - acc: 0.8988 - val_loss: 1.0641 - val_acc: 0.9005
# Epoch 5/40
# 50000/50000 [==============================] - 3s 68us/step - loss: 1.0141 - acc: 0.9085 - val_loss: 0.9585 - val_acc: 0.9153
# Epoch 6/40
# 50000/50000 [==============================] - 3s 61us/step - loss: 0.9416 - acc: 0.9154 - val_loss: 0.9210 - val_acc: 0.9090
# Epoch 7/40
# ...

# %%
#9 L2 regularized model for three layers
nw_l2_3layer = models.Sequential()
nw_l2_3layer.add(layers.Dense(512, activation='relu', input_shape=(28 * 28,), kernel_regularizer=regularizers.l2(0.001)))
nw_l2_3layer.add(layers.Dense(512, activation='relu', kernel_regularizer=regularizers.l2(0.001)))
nw_l2_3layer.add(layers.Dense(10, activation='softmax'))
nw_l2_3layer.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])
result_l2_3layer = nw_l2_3layer.fit(train_images, train_labels,validation_data=(valid_images,valid_labels), epochs=40, batch_size=512)
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/40
# 50000/50000 [==============================] - 5s 97us/step - loss: 1.1227 - acc: 0.8684 - val_loss: 0.6765 - val_acc: 0.9437
# Epoch 2/40
# 50000/50000 [==============================] - 3s 59us/step - loss: 0.5588 - acc: 0.9442 - val_loss: 0.4350 - val_acc: 0.9544
# Epoch 3/40
# 50000/50000 [==============================] - 3s 66us/step - loss: 0.3782 - acc: 0.9572 - val_loss: 0.3494 - val_acc: 0.9537
# Epoch 4/40
# 50000/50000 [==============================] - 3s 61us/step - loss: 0.2959 - acc: 0.9632 - val_loss: 0.2812 - val_acc: 0.9614
# Epoch 5/40
# 50000/50000 [==============================] - 3s 64us/step - loss: 0.2503 - acc: 0.9667 - val_loss: 0.2960 - val_acc: 0.9484
# Epoch 6/40
# 50000/50000 [==============================] - 3s 63us/step - loss: 0.2228 - acc: 0.9700 - val_loss: 0.2118 - val_acc: 0.9704
# Epoch 7/40
# ...

# %%
#10 Initial model for five layers and 300 hiden nits
nw_5layer_300h = models.Sequential()
nw_5layer_300h.add(layers.Dense(300, activation='relu', input_shape=(28 * 28,)))
nw_5layer_300h.add(layers.Dense(300, activation='relu'))
nw_5layer_300h.add(layers.Dense(300, activation='relu'))
nw_5layer_300h.add(layers.Dense(300, activation='relu'))
nw_5layer_300h.add(layers.Dense(10, activation='softmax'))
nw_5layer_300h.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])

result_nw_5layer_300h = nw_5layer_300h.fit(train_images, train_labels,validation_data=(valid_images,valid_labels), epochs=40, batch_size=512)
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/40
# 50000/50000 [==============================] - 4s 84us/step - loss: 0.4898 - acc: 0.8414 - val_loss: 0.2699 - val_acc: 0.9143
# Epoch 2/40
# 50000/50000 [==============================] - 2s 47us/step - loss: 0.1694 - acc: 0.9471 - val_loss: 0.1125 - val_acc: 0.9645
# Epoch 3/40
# 50000/50000 [==============================] - 2s 47us/step - loss: 0.1101 - acc: 0.9666 - val_loss: 0.1021 - val_acc: 0.9686
# Epoch 4/40
# 50000/50000 [==============================] - 2s 46us/step - loss: 0.0814 - acc: 0.9753 - val_loss: 0.1173 - val_acc: 0.9650
# Epoch 5/40
# 50000/50000 [==============================] - 2s 48us/step - loss: 0.0577 - acc: 0.9818 - val_loss: 0.0903 - val_acc: 0.9733
# Epoch 6/40
# 50000/50000 [==============================] - 2s 50us/step - loss: 0.0445 - acc: 0.9857 - val_loss: 0.0945 - val_acc: 0.9728
# Epoch 7/40
# ...

# %%
val_loss_drop_4layer = result_drop_4layer.history['val_loss']
val_loss_drop_3layer = result_drop_3layer.history['val_loss']
val_loss_drop_6layer = result_drop_6layer.history['val_loss']
val_loss_drop_5layer_03r = result_drop_5layer_03r.history['val_loss']
val_loss_drop_5layer_07r = result_drop_5layer_07r.history['val_loss']
val_loss_5layer_300bs = result_nw_5layer_300bs.history['val_loss']
val_loss_5layer_700bs = result_nw_5layer_700bs.history['val_loss']
val_loss_l1_3layer = result_l1_3layer.history['val_loss']
val_loss_l2_3layer = result_l2_3layer.history['val_loss']
val_loss_5layer_300h = result_nw_5layer_300h.history['val_loss']

plt.figure(figsize=(12, 10))

plt.plot(val_loss_drop_4layer)
plt.plot(val_loss_drop_3layer)
plt.plot(val_loss_drop_6layer)
plt.plot(val_loss_drop_5layer_03r) 
plt.plot(val_loss_drop_5layer_07r)
plt.plot(val_loss_5layer_300bs)
plt.plot(val_loss_5layer_700bs)
plt.plot(val_loss_l1_3layer)
plt.plot(val_loss_l2_3layer)
plt.plot(val_loss_5layer_300h) 

plt.legend(['val_loss_drop_4layer', 'val_loss_drop_3layer', 'val_loss_drop_6layer',
            'val_loss_drop_5layer_03r', 'val_loss_drop_5layer_07r','val_loss_5layer_300bs',
            'val_loss_5layer_700bs', 'val_loss_l1_3layer', 'val_loss_l2_3layer', 'val_loss_5layer_300h'])
         
plt.title('Validation Loss in Alternative Models')
plt.show()

# %% [markdown]
# Obviously, dropout models have better performance. The dropout model (3 layer, 512 hiden units, 512 batch size, 40 epochs, 0.5 dropout rate) has the best and constant performance. And dropout model (6 layer, 512 hiden units, 512 batch size, 40 epochs, 0.5 dropout rate) and dropout model (5 layer, 512 hiden units, 512 batch size, 40 epochs, 0.5 dropout rate) also perform very well.

# %% [markdown]
# ## 4. Final Model

# %% [markdown]
# **Reestimate that model using all of the training data (no validation set) with the same hyperparameter values**

# %%
result_best = nw_drop_3layer.fit(train_images, train_labels, epochs=40, batch_size=512)
# Out:
# Epoch 1/40
# 50000/50000 [==============================] - 3s 64us/step - loss: 0.0241 - acc: 0.9928
# Epoch 2/40
# 50000/50000 [==============================] - 3s 61us/step - loss: 0.0231 - acc: 0.9923
# Epoch 3/40
# 50000/50000 [==============================] - 3s 50us/step - loss: 0.0234 - acc: 0.9926
# Epoch 4/40
# 50000/50000 [==============================] - 3s 54us/step - loss: 0.0241 - acc: 0.9925
# Epoch 5/40
# 50000/50000 [==============================] - 3s 52us/step - loss: 0.0223 - acc: 0.9935
# Epoch 6/40
# 50000/50000 [==============================] - 3s 57us/step - loss: 0.0216 - acc: 0.9939
# Epoch 7/40
# 50000/50000 [==============================] - 3s 52us/step - loss: 0.0222 - acc: 0.9931
# Epoch 8/40
# 50000/50000 [==============================] - 3s 52us/step - loss: 0.0207 - acc: 0.9936
# Epoch 9/40
# 50000/50000 [==============================] - 3s 52us/step - loss: 0.0228 - acc: 0.9932
# Epoch 10/40
# ...

# %% [markdown]
# **Calcuate the test set loss and accuracy. How well does the model generalize?**

# %%
nw_drop_3layer.evaluate(test_images, test_labels)
# Out:
# 10000/10000 [==============================] - 1s 60us/step
# [0.10207198109140614, 0.9849]

# %% [markdown]
# The test set loss and accuracy of the 0.1021 and 0.9849 and it generalizes very well.

# %% [markdown]
# **Why do you think this model performed better/worse than your other model configurations? What about the design of the network led to improved performace?**

# %% [markdown]
# This model performed better than other model configurations. Firstly, dropout model would perform better on average since it reduce the overfitting, that is why my dropour models in last question have good performance. Secondly, fewer layer reduces the complexity of the model and thus avoids high dimension problem.
